# %% [markdown]
# # Week 5 — you can now see the story inside data 📊
# # EDA is a skill that compounds — the more you practise it, the faster your intuition develops
#
# # 1. EDA Checklist
# # Any Week 1–4 dataset → 8-step checklist → histograms + box plots
#
# # 2. Distribution Deep Dive
# # 5-city weather data → outlier detection → KDE curves + box plots
#
# # 3. Correlation Analysis
# # 50-student CSV → heatmap → scatter plots → written analysis
#
# # 4. Full EDA Report
# # Any real API → 5 charts → 8–10 written observations

# %%
# Here’s the short and perfect summary of Week 5 tasks:

# EDA Checklist: Apply the 8-step checklist on any dataset from Weeks 1–4, including histograms and box plots.

# Distribution Deep Dive: Use 5-city weather data to detect outliers and visualize with KDE curves and box plots.

# Correlation Analysis: Create a 50-student dataset, run a correlation heatmap, scatter plots, and provide written analysis.

# Full EDA Report: Fetch a real dataset from a public API, clean it, run full EDA, produce at least 5 labelled charts, and write 8–10 insights. Bonus: use sns.pairplot() to highlight the most interesting relationship.

# 👉 In essence: Week 5 is about telling the story inside data — practising EDA across synthetic and real datasets, building intuition with distributions, correlations, and full reports.
